# %%
import os, json,time, re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import seaborn as sns
import scipy.io as sio
import pandas as pd
from operator import truediv
from sklearn.manifold import TSNE
from sklearn.decomposition import IncrementalPCA,  PCA
from sklearn.metrics import accuracy_score, classification_report, cohen_kappa_score, confusion_matrix
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import cdist
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.callbacks import EarlyStopping
from keras.losses import categorical_crossentropy
from keras.utils import to_categorical
from keras.layers import (Conv3D, Conv2D, Conv1D, MaxPooling1D, Dense, Dropout,
                          Flatten, Input, Reshape, MaxPooling2D, SeparableConv2D,
                          MaxPooling3D, MaxPooling2D, GlobalAveragePooling2D,
                          BatchNormalization, GlobalAveragePooling3D, concatenate, Reshape)

# %%
## Loading Hyperspectral Datasets

def LoadHSIData(method):
    data_path = "/kaggle/input/dataset"
    if method == 'HH':
        HSI = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu.mat'))['WHU_Hi_HongHu']
        GT = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HongHu_gt'))['WHU_Hi_HongHu_gt']
        Num_Classes = 22
        target_names = ['Red roof', 'Road', 'Bare soil', 'Cotton',
                        'Cotton firewood', 'Rape', 'Chinese cabbage',
                        'Pakchoi', 'Cabbage', 'Tuber mustard', 'Brassica parachinensis',
                        'Brassica chinensis', 'Small Brassica chinensis', 'Lactuca sativa',
                        'Celtuce', 'Film covered lettuce', 'Romaine lettuce',
                        'Carrot', 'White radish', 'Garlic sprout', 'Broad bean',
                        'Tree']
    elif method == 'HC':
        HSI = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan.mat'))['WHU_Hi_HanChuan']
        GT = sio.loadmat(os.path.join(data_path, 'WHU_Hi_HanChuan_gt'))['WHU_Hi_HanChuan_gt']
        Num_Classes = 16
        target_names = ['Strawberry', 'Cowpea', 'Soybean', 'Sorghum',
                        'Water spinach', 'Watermelon', 'Greens', 'Trees', 'Grass',
                        'Red roof', 'Gray roof', 'Plastic', 'Bare soil', 'Road',
                        'Bright object', 'Water']
    elif method == 'Qingyun':
      HSI = sio.loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
      GT = sio.loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
      Num_Classes = 6
      target_names = ["Trees", "Concrete building", "Car", "Ironhide building",
                      "Plastic playground", "Asphalt road"]
    elif method == 'SA':
        HSI = sio.loadmat(os.path.join(data_path, 'Salinas_corrected.mat'))['salinas_corrected']
        GT = sio.loadmat(os.path.join(data_path, 'Salinas_gt.mat'))['salinas_gt']
        Num_Classes = 16
        target_names = ['Weeds_1','Weeds_2','Fallow',
                        'Fallow_rough_plow','Fallow_smooth', 'Stubble','Celery',
                        'Grapes_untrained','Soil_vinyard_develop','Corn_Weeds',
                        'Lettuce_4wk','Lettuce_5wk','Lettuce_6wk',
                        'Lettuce_7wk', 'Vinyard_untrained','Vinyard_trellis']
    elif method == 'PU':
        HSI = sio.loadmat('/kaggle/input/dataset/dataset/PU/PaviaU.mat')['paviaU']
        GT = sio.loadmat('/kaggle/input/dataset/dataset/PU/PaviaU_gt.mat')['paviaU_gt']
        Num_Classes = 9
        target_names = ['Asphalt','Meadows','Gravel','Trees', 'Painted','Soil','Bitumen',
                        'Bricks','Shadows']
    elif method == 'UH':
      HSI = sio.loadmat(os.path.join(data_path, 'HU.mat'))['HSI']
      GT = sio.loadmat(os.path.join(data_path, 'HU_gt.mat'))['gt']
      Num_Classes = 15
      target_names = ['Healthy grass', 'Stressed grass', 'Synthetic grass', 'Trees',
                    'Soil', 'Water', 'Residential', 'Commercial', 'Road',
                    'Highway', 'Railway', 'Parking Lot 1', 'Parking Lot 2',
                    'Tennis Court', 'Running Track']
    elif method == 'IP':
      HSI = sio.loadmat('/kaggle/input/datasetssst/Indian_pines_corrected.mat')['indian_pines_corrected']
      GT = sio.loadmat('/kaggle/input/datasetssst/Indian_pines_gt.mat')['indian_pines_gt']
      Num_Classes = 16
      target_names = ['Alfalfa', 'Corn-notill', 'Corn-mintill', 'Corn', 'Grass-pasture', 'Grass-trees',
                      'Grass-pasture-mowed', 'Hay-windrowed', 'Oats', 'Soybean-notill', 'Soybean-mintill',
                      'Soybean-clean', 'Wheat', 'Woods', 'Buildings-Grass-Trees-Drives', 'Stone-Steel-Towers']
    
    return HSI, GT, Num_Classes, target_names

# %%
## Dimensional Reduction Method (If required)
def DLMethod(method, HSI, NC = 75):
    RHSI = np.reshape(HSI, (-1, HSI.shape[2]))
    if method == 'PCA': ## PCA
        pca = PCA(n_components = NC, whiten = True)
        RHSI = pca.fit_transform(RHSI)
        RHSI = np.reshape(RHSI, (HSI.shape[0], HSI.shape[1], NC))
    elif method == 'iPCA': ## Incremental PCA
        n_batches = 256
        inc_pca = IncrementalPCA(n_components = NC)
        for X_batch in np.array_split(RHSI, n_batches):
          inc_pca.partial_fit(X_batch)
        X_ipca = inc_pca.transform(RHSI)
        RHSI = np.reshape(X_ipca, (HSI.shape[0], HSI.shape[1], NC))
    return RHSI

# %%
def TrTeSplit(HSI, GT, trRatio, vrRatio, teRatio, randomState=345):
    # Split into train and test sets
    Tr, Te, TrC, TeC = train_test_split(HSI, GT, test_size=teRatio,
                                        random_state=randomState, stratify=GT)
    # Calculate the validation ratio based on the updated test and train ratios
    totalTrRatio = trRatio + vrRatio
    new_vrRatio = vrRatio / totalTrRatio
    # Split train set into train and validation sets
    Tr, Va, TrC, VaC = train_test_split(Tr, TrC, test_size=new_vrRatio,
                                        random_state=randomState, stratify=TrC)

    return Tr, Va, Te, TrC, VaC, TeC

# %%
HSID = "IP" ## "LK", "HC", "HH", Qingyun, Pingan, Tangdaowan
DLM = "PCA" ## "PCA", "iPCA"
WS = 8
teRatio = 0.50
vrRatio = 0.90
trRatio = 0.10
k = 15
#adam = tf.keras.optimizers.legacy.Adam(lr = 0.001, decay = 1e-06)
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True
)
adam = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

epochs = 20
batch_size = 56

# %%
## Creat Patches for 3D (Spatial-Spectral) Models
def ImageCubes(HSI, GT, WS=WS, removeZeroLabels=True):
    num_rows, num_cols, num_bands = HSI.shape
    margin = int(WS / 2)
    padded_data = np.pad(HSI, ((margin, margin), (margin, margin), (0, 0)), mode='constant')
    image_cubes = np.zeros((num_rows * num_cols, WS, WS, num_bands))
    patchesLabels = np.zeros((num_rows * num_cols))
    patchIndex = 0
    for r in range(margin, num_rows + margin):
        for c in range(margin, num_cols + margin):
            cube = padded_data[r - margin: r + margin, c - margin: c + margin, :]
            image_cubes[patchIndex, :, :, :] = cube
            patchesLabels[patchIndex] = GT[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
      image_cubes = image_cubes[patchesLabels>0,:,:,:]
      patchesLabels = patchesLabels[patchesLabels>0]
      patchesLabels -= 1
    return image_cubes, patchesLabels

# %%
## Assigning Class Labels for Final Classification and Confusion Matrices
def ClassificationReports(TeC, Te_Pred, target_names):
    classification = classification_report(np.argmax(TeC, axis=1), np.argmax(Te_Pred, axis=1), target_names = target_names)
    oa = accuracy_score(np.argmax(TeC, axis=1), np.argmax(Te_Pred, axis=1))
    confusion = confusion_matrix(np.argmax(TeC, axis=1), np.argmax(Te_Pred, axis=1))
    list_diag = np.diag(confusion)
    list_raw_sum = np.sum(confusion, axis=1)
    each_acc = np.nan_to_num(truediv(list_diag, list_raw_sum))
    aa = np.mean(each_acc)
    kappa = cohen_kappa_score(np.argmax(TeC, axis=1), np.argmax(Te_Pred, axis=1))
    return classification, confusion, oa*100, each_acc*100, aa*100, kappa*100

## Writing Results in CSV files
def CSVResults(file_name, classification, Confusion, Parameters, 
                          Flops, Tr_time, Te_Time, Kappa, OA, AA, Per_Class):
    classification = str(classification)
    confusion = str(Confusion)
    with open(file_name, 'w') as CSV_file:
      CSV_file.write('{} Tr_Time'.format(Tr_time))
      CSV_file.write('\n')
      CSV_file.write('{} Te_Time'.format(Te_Time))
      CSV_file.write('\n')
      CSV_file.write('{} Flops'.format(Flops))
      CSV_file.write('\n')
      CSV_file.write('{} Parameters'.format(Parameters))
      CSV_file.write('\n')
      CSV_file.write('{} Kappa accuracy (%)'.format(Kappa))
      CSV_file.write('\n')
      CSV_file.write('{} Overall accuracy (%)'.format(OA))
      CSV_file.write('\n')
      CSV_file.write('{} Average accuracy (%)'.format(AA))
      CSV_file.write('\n')
      CSV_file.write('{}'.format(Per_Class))
      CSV_file.write('\n')
      CSV_file.write('{}'.format(classification))
      CSV_file.write('\n')
      CSV_file.write('{}'.format(Confusion))
    return CSV_file

## Plot Ground Truths
def GT_Plot(CRDHSI, GT, model, WS, k):
  Predicted = model.predict(CRDHSI)
  Predicted = np.argmax(Predicted, axis=1)
  height, width = np.shape(GT)
  ## Calculate the predicted Ground Truths
  outputs = np.zeros((height, width))
  count = 0
  for AA in range(height):
    for BB in range(width):
      target = int(GT[AA,BB])
      if target == 0:
        continue
      else:
        outputs[AA][BB] = Predicted[count]
        count = count+1
  return outputs

# %%
## Main Function to load Datasets, Dimensional Reduction and Creating Patchs
HSI, GT, Num_Classes, target_names = LoadHSIData(HSID)
start = time.time()
RDHSI = DLMethod(DLM, HSI, NC = k)
end = time.time()
DL_Time = end - start
CRDHSI, CGT = ImageCubes(RDHSI, GT, WS = WS)
Tr, Va, Te, TrC, VaC, TeC = TrTeSplit(CRDHSI, CGT, trRatio, vrRatio, teRatio)
TrC = to_categorical(TrC)
VaC = to_categorical(VaC)
TeC = to_categorical(TeC)
CHSI = to_categorical(CGT)

# %%
# Compute the Flops
def get_flops(model):
    total_flops = 0
    for layer in model.layers:
        flops = 0
        if isinstance(layer, tf.keras.layers.Conv2D):
            kernel_size = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            flops = kernel_size * layer.output_shape[1] * layer.output_shape[2] * layer.filters
        elif isinstance(layer, tf.keras.layers.Dense):
            flops = layer.input_shape[-1] * layer.units
        elif isinstance(layer, tf.keras.layers.Flatten):
            continue
        total_flops += flops
    return total_flops

def compute_flops(model):
    flops = get_flops(model)
    return flops

# %%
# Count samples per class
def count_class_samples(labels, num_classes):
    class_counts = {f"class_{i}": 0 for i in range(num_classes)}
    for label in labels:
        class_index = np.argmax(label)
        class_counts[f"class_{class_index}"] += 1
    return class_counts

# %%
# Positional Encodding 
def get_positional_encoding_ssvit(max_len, d_emb):
    pos = np.arange(max_len)[:, np.newaxis]
    i = np.arange(d_emb)[np.newaxis, :]
    angles = pos / np.power(10000, 2 * i / d_emb)
    positional_encoding = np.zeros((max_len, d_emb))
    positional_encoding[:, ::2] = np.sin(angles[:, ::2])
    positional_encoding[:, 1::2] = np.cos(angles[:, 1::2])
    return positional_encoding[np.newaxis, ...]

# %%
## Class tokens
class ClassTokenLayer(tf.keras.layers.Layer):
    def __init__(self, embedding_dim, **kwargs):
        super(ClassTokenLayer, self).__init__(**kwargs)
        self.embedding_dim = embedding_dim

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, 1, self.embedding_dim),
            initializer=tf.zeros_initializer(),
            trainable=False)
    
    def call(self, inputs):
        cls_token_broadcasted = tf.broadcast_to(self.cls_token, [tf.shape(inputs)[0], 1, 1, 1, self.embedding_dim])
        return tf.concat([cls_token_broadcasted, inputs], axis=1)

# %%
# Spatial-Spectral Transformer
class SST(tf.keras.layers.Layer):
    def __init__(self,num_heads, transformer_layer_depth, d_model, dff, dropout_rate=0.1, layernorm_eps=1e-6, **kwargs):
        super(SST, self).__init__(**kwargs)
        self.num_heads = num_heads
        self.transformer_layer_depth = transformer_layer_depth
        self.d_model = d_model
        self.dff = dff
        self.dropout_rate = dropout_rate
        self.layernorm_eps = layernorm_eps
        self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model)
        self.dropout1 = tf.keras.layers.Dropout(dropout_rate)
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=layernorm_eps)
        self.dense1 = tf.keras.layers.Dense(dff, activation="relu")
        self.dense2 = tf.keras.layers.Dense(d_model)
        self.dropout2 = tf.keras.layers.Dropout(dropout_rate)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=layernorm_eps)

    def call(self, inputs, training):
        x = inputs
        for i in range(self.transformer_layer_depth):
            attn_output = self.mha(x, x)
            attn_output = self.dropout1(attn_output, training=training)
            attn_output = self.layernorm1(x + attn_output)
            ffn_output = self.dense1(attn_output)
            ffn_output = self.dense2(ffn_output)
            ffn_output = self.dropout2(ffn_output, training=training)
            ffn_output = self.layernorm2(attn_output + ffn_output)
            x = ffn_output
        return x

# %%
from tensorflow.keras.layers import Layer, Input, Conv3D, Dense, Add
import tensorflow as tf

# Define the ExpandDimsLayer as you provided
class ExpandDimsLayer(Layer):
    def __init__(self, axis, **kwargs):
        super(ExpandDimsLayer, self).__init__(**kwargs)
        self.axis = axis
    
    def call(self, inputs):
        return tf.expand_dims(inputs, axis=self.axis)

from tensorflow.keras.layers import Layer

class CrossAttentionLayer(Layer):
    def __init__(self, embedding_dim, **kwargs):
        super(CrossAttentionLayer, self).__init__(**kwargs)
        self.embedding_dim = embedding_dim
    
    def call(self, inputs, training=False):
        q, k, v = inputs
        # Compute the cross-attention
        cross_attn_output = tf.matmul(q[:, tf.newaxis, :], k, transpose_b=True)
        cross_attn_output = cross_attn_output / tf.math.sqrt(
            tf.cast(self.embedding_dim, dtype=tf.float32)
        )
        cross_attn_output = tf.nn.softmax(cross_attn_output, axis=-1)
        cross_attn_output = tf.matmul(cross_attn_output, v)
        return cross_attn_output


# Custom Concatenate Layer
class ConcatenateLayer(Layer):
    def __init__(self, **kwargs):
        super(ConcatenateLayer, self).__init__(**kwargs)
    
    def call(self, inputs, **kwargs):
        transformer_output, cross_attn_output = inputs
        # Concatenate the outputs and pass through dense layers
        concat_output = tf.concat([transformer_output[:, 0, 0, 0], cross_attn_output[:, 0, 0, 0]], axis=-1)
        return concat_output


def SSViT(WS, k, Num_Classes, num_transformer_layers=4, num_heads=8, dff=4 * 64, dropout_rate=0.1, layernorm_eps=1e-3, training=False):
    input_shape = (WS, WS, k)
    max_patch_size = min(input_shape[:3])
    patch_size = max_patch_size
    num_patches = ((input_shape[0] // patch_size) * (input_shape[1] // patch_size) * (input_shape[2] // patch_size))
    embedding_dim = 64
    inputs = Input(shape=input_shape, name="inputs")
    
    # Replace tf.expand_dims with the custom ExpandDimsLayer
    x = ExpandDimsLayer(axis=1)(inputs)
    
    patch_embed = Conv3D(embedding_dim, kernel_size=(1, patch_size, patch_size),
        strides=(1, patch_size, patch_size), padding="valid", name="patch_embed")(x)
    
    cls_token_layer = ClassTokenLayer(embedding_dim=embedding_dim)
    patch_embed = cls_token_layer(patch_embed)
    
    pos_encoding = get_positional_encoding_ssvit(num_patches + 1, embedding_dim)
    patch_embed = patch_embed + pos_encoding
    
    # Transformer layers
    for i in range(num_transformer_layers):
        if i == 0:
            transformer_layer = SST(num_heads=num_heads, transformer_layer_depth=1,
                d_model=embedding_dim, dff=dff, name=f"transformer_layer_{i}")(patch_embed, training=training)
        else:
            transformer_layer = SST(num_heads=num_heads, transformer_layer_depth=1,
                d_model=embedding_dim, dff=dff, name=f"transformer_layer_{i}")(transformer_layer, training=training)
    
    # Cross-attention layer
    q = Dense(embedding_dim)(transformer_layer[:, 0, 0, 0])
    k = Dense(embedding_dim)(patch_embed[:, 1:, :, :, :])
    v = patch_embed[:, 1:, :, :, :]
    
    cross_attn_layer = CrossAttentionLayer(embedding_dim)
    cross_attn_output = cross_attn_layer([q, k, v], training=training)
    
    # Concatenate the outputs using the custom ConcatenateLayer
    concat_layer = ConcatenateLayer()
    concat_output = concat_layer([transformer_layer, cross_attn_output])

    # Pass through dense layers
    output_layer = Dense(dff, activation="relu")(concat_output)
    output_layer = Dense(dff, activation="relu")(output_layer)
    output_layer = Dense(Num_Classes, activation="softmax", name="output_layer")(output_layer)
    
    # Create and return the model
    model = Model(inputs=inputs, outputs=output_layer, name="SSViT")
    return model

# %%
# Uncertainty Sampling
def uncertainty_sampling(model, X_pool, query_size):
    probs = model.predict(X_pool)
    uncertainty = -np.max(probs, axis=1)  # Lower max prob indicates higher uncertainty
    query_indices = np.argsort(uncertainty)[-query_size:]  # Get indices of most uncertain samples
    return query_indices

# %%
# Diversity Sampling 
def diversity_sampling(X_pool, query_size):
    num_samples, H, W, C = X_pool.shape
    query_indices = []
    neighborhood_size=3
    half_size = neighborhood_size // 2
    for i in range(num_samples):
        current_sample = X_pool[i]
        diversity_values = np.zeros((H, W))
        for h in range(half_size, H - half_size):
            for w in range(half_size, W - half_size):
                neighborhood = current_sample[h - half_size:h + half_size + 1, w - half_size:w + half_size + 1, :]
                reshaped_neighborhood = neighborhood.reshape(-1, C)
                distances = cdist(reshaped_neighborhood, reshaped_neighborhood, metric='euclidean')
                diversity_metric = np.mean(distances)
                diversity_values[h, w] = diversity_metric
        flat_diversity_values = diversity_values.flatten()
        query_indices = np.argsort(flat_diversity_values)[-query_size:]
    return query_indices

# %%
# Hybrid Query
def hybrid_query_strategy(model, X_pool, query_size):
    uncertainty_indices = uncertainty_sampling(model, X_pool, query_size)
    diversity_indices = diversity_sampling(X_pool, query_size)
    query_indices = np.unique(np.concatenate((uncertainty_indices, diversity_indices)))
    return query_indices[:query_size]

# %%
def compute_flops(model):
    flops = 0
    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.Conv2D):
            # For Conv2D layers, the number of FLOPs is calculated as:
            # (Kernel Height * Kernel Width * Input Channels * Output Channels * Output Height * Output Width)
            kernel_size = np.prod(layer.kernel_size)
            output_shape = layer.output_shape[1:]  # Exclude batch size
            input_channels = layer.input_shape[-1]
            output_channels = layer.filters
            output_height, output_width = output_shape[0], output_shape[1]
            flops += kernel_size * input_channels * output_channels * output_height * output_width
        elif isinstance(layer, tf.keras.layers.Dense):
            # For Dense layers, the number of FLOPs is:
            # (Number of Inputs * Number of Units)
            input_units = layer.input.shape[-1]  # Use layer.input to get input shape
            output_units = layer.units
            flops += input_units * output_units
        elif isinstance(layer, tf.keras.layers.Flatten):
            continue  # No FLOPs for Flatten layer
        elif isinstance(layer, tf.keras.layers.MaxPooling2D) or isinstance(layer, tf.keras.layers.AveragePooling2D):
            # For Pooling layers, it's kernel size * output size
            pool_size = np.prod(layer.pool_size)
            output_shape = layer.output_shape[1:]
            flops += pool_size * np.prod(output_shape)
    return flops

# %%
# ATL-SST
from tensorflow.keras.optimizers import Adam
def main_pipeline(WS, k, Num_Classes, CRDHSI, GT, Tr, TrC, Va, VaC, Te, TeC, num_iterations, query_percentage, epochs, batch_size):
    model = SSViT(WS, k, Num_Classes)
    optimizer = Adam(learning_rate=1e-4)

    # Then compile the model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    #model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
    # Initialize a dictionary to store sample counts
    sample_counts = {
        "initial_training_samples": Tr.shape[0],
        "initial_Train_class_counts": count_class_samples(TrC, Num_Classes),
        "initial_validation_samples": Va.shape[0],
        "initial_Val_class_counts": count_class_samples(VaC, Num_Classes),
        "Test_samples": Te.shape[0],
        "class_Test_counts": count_class_samples(TeC, Num_Classes),
        "iterations": []
    }
    # Initial training
    start_time = time.time()
    model.fit(x=Tr, y=TrC, batch_size=batch_size, epochs=epochs, validation_data=(Va, VaC))
    training_time = time.time() - start_time
    # Compute FLOPs for the initial model
    initial_flops = compute_flops(model)
    # Record initial counts
    sample_counts["iterations"].append({
        "iteration": 1,
        "training_samples": Tr.shape[0],
        "class_train_counts": count_class_samples(TrC, Num_Classes),
        "validation_samples": Va.shape[0],
        "class_Val_counts": count_class_samples(VaC, Num_Classes), 
        "Test_samples": Te.shape[0],
        "class_Test_counts": count_class_samples(TeC, Num_Classes)
    })
    
    ## Test Phase 
    start = time.time()
    Te_Pre = model.predict(Te)
    end = time.time()
    Te_Time = end - start
    trainable_parameters = model.count_params()
    classification, Confusion, OA, Per_Class, AA, Kappa = ClassificationReports(TeC, Te_Pre, target_names)
    file_name = f"1_{HSID}_{trRatio}_{WS}_Classification_Report.csv"
    CSV_file = CSVResults(file_name, classification, Confusion, trainable_parameters, 
                          initial_flops, training_time, Te_Time, Kappa, OA, AA, Per_Class)

    # Ground Truths for inital Training
    outputs = GT_Plot(CRDHSI, GT, model, WS, k)
    plt.figure(figsize=(10, 10))
    plt.imshow(outputs, cmap=None)
    plt.axis('off')
    file_name = f"1_{HSID}_{trRatio}_{WS}_Ground_Truths.png"
    plt.savefig(file_name, dpi=500, format='png', bbox_inches='tight', pad_inches=0)
    
    # Active Learning Iterations
    for i in range(1, num_iterations+1):
        print(f"Active Learning Iteration {i}/{num_iterations}")
        # Query new samples from the pool using uncertainty sampling
        query_size = int(query_percentage * Va.shape[0])
        query_indices = hybrid_query_strategy(model, Va, query_size)
        queried_X = Va[query_indices]
        queried_y = VaC[query_indices]
        
        # Add queried samples back to the training set
        Tr = np.concatenate([Tr, queried_X], axis=0)
        TrC = np.concatenate([TrC, queried_y], axis=0)
        # Remove queried samples from the pool
        Va = np.delete(Va, query_indices, axis=0)
        VaC = np.delete(VaC, query_indices, axis=0)
        # Record counts after querying
        sample_counts["iterations"].append({
            "iteration": i+1,
            "training_samples": Tr.shape[0],
            "class_train_counts": count_class_samples(TrC, Num_Classes),
            "validation_samples": Va.shape[0],
            "class_Val_counts": count_class_samples(VaC, Num_Classes)
        })
        # freeze feature learning layers and fine-tune classification layers
        for layer in model.layers[:-3]:
            layer.trainable = False
        # Fine-tuning the model
        fine_tune_start_time = time.time()
        history = model.fit(x=Tr, y=TrC, batch_size=batch_size, epochs=epochs, validation_data=(Va, VaC))
        fine_tune_time = time.time() - fine_tune_start_time
        # Compute FLOPs for the Fine_tuned model
        Fine_tuned_flops = compute_flops(model)
        Finetuned_parameters = model.count_params()
        ## Test Phase 
        start = time.time()
        Te_Pre = model.predict(Te)
        end = time.time()
        Te_Time = end - start
        ## Classification Report for Test Model
        classification, Confusion, OA, Per_Class, AA, Kappa = ClassificationReports(TeC, Te_Pre, target_names)
        file_name = f"{i+1}_{HSID}_{trRatio}_{WS}_Classification_Report.csv"
        CSV_file = CSVResults(file_name, classification, Confusion, Finetuned_parameters, 
                          Fine_tuned_flops, fine_tune_time, Te_Time, Kappa, OA, AA, Per_Class)
        # Ground Truths
        outputs = GT_Plot(CRDHSI, GT, model, WS, k)
        plt.figure(figsize=(10, 10))
        plt.imshow(outputs, cmap=None)
        plt.axis('off')
        file_name = f"{i+1}_{HSID}_{trRatio}_{WS}_Ground_Truths.png"
        plt.savefig(file_name, dpi=500, format='png', bbox_inches='tight', pad_inches=0)
        # Save the model during the last iteration
        if i == num_iterations:
            model.save(f"{HSID}_trained_ssvit_model.tf")
            print(f"Model saved at iteration {i} as 'final_model_iteration.tf'")

    # Save sample counts to a file
    sample_counts_filename = f"{HSID}_{trRatio}_{WS}_sample_counts.json"
    with open(sample_counts_filename, 'w') as f:
        json.dump(sample_counts, f, indent=4)    
    # Extract training and validation metrics
    accuracy = history.history['accuracy']
    loss = history.history['loss']
        # Check if validation metrics exist
    val_accuracy = history.history.get('val_accuracy', [])
    val_loss = history.history.get('val_loss', [])
    # Create a DataFrame
    history_df = pd.DataFrame({
        'Epoch': range(1, len(accuracy) + 1),
        'Training Accuracy': accuracy,
        'Training Loss': loss,
        'Validation Accuracy': val_accuracy if val_accuracy else ['N/A'] * len(accuracy),
        'Validation Loss': val_loss if val_loss else ['N/A'] * len(accuracy)
    })
    # Save to CSV
    history_df.to_csv(f"{HSID}_training_history.csv", index=False)
    return model
# Main
model = main_pipeline(WS, k, Num_Classes, CRDHSI, GT, Tr, TrC, Va, VaC, Te, TeC, num_iterations=5, 
                      query_percentage=0.02, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.1180 - loss: 2.6657 - val_accuracy: 0.2706 - val_loss: 2.2930
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2852 - loss: 2.2281 - val_accuracy: 0.3697 - val_loss: 2.0859
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3782 - loss: 2.0436 - val_accuracy: 0.4575 - val_loss: 1.8866
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4623 - loss: 1.8232 - val_accuracy: 0.4980 - val_loss: 1.7035
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5521 - loss: 1.5830 - val_accuracy: 0.5126 - val_loss: 1.5381
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5804 - loss: 1.3442 - val_accuracy: 0.5392 - val_loss: 1.3943
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6042 - loss: 1.2648 - val_accuracy: 0.5648 - val_loss: 1.2852
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6299 - loss: 1.1404 - val_accuracy: 0.5911 - val_loss: 1.1944
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6653 - loss: 1.0167 - val_accuracy: 0.6119 - val_loss: 1.1280
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7234 - loss: 0.8788 - val_accuracy: 0.6457 - val_loss: 1.0664
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7917 - loss: 0.7933 - val_accuracy: 0.6570 - val_loss: 1.0220
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8310 - loss: 0.6587 - val_accuracy: 0.6741 - val_loss: 0.9779
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8332 - loss: 0.6332 - val_accuracy: 0.6932 - val_loss: 0.9504
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8701 - loss: 0.5608 - val_accuracy: 0.7016 - val_loss: 0.9367
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8839 - loss: 0.4705 - val_accuracy: 0.7144 - val_loss: 0.9028
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9102 - loss: 0.4025 - val_accuracy: 0.7231 - val_loss: 0.8898
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9312 - loss: 0.3720 - val_accuracy: 0.7157 - val_loss: 0.8970
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9410 - loss: 0.3225 - val_accuracy: 0.7207 - val_loss: 0.8945
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9690 - loss: 0.2409 - val_accuracy: 0.7255 - val_loss: 0.8888
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9521 - loss: 0.2460 - val_accuracy: 0.7288 - val_loss: 0.8953
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step
#   1/321 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Active Learning Iteration 1/5
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# Epoch 1/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9042 - loss: 0.3916 - val_accuracy: 0.7305 - val_loss: 0.8940
# Epoch 2/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9264 - loss: 0.2842 - val_accuracy: 0.7416 - val_loss: 0.8703
# Epoch 3/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9585 - loss: 0.2329 - val_accuracy: 0.7325 - val_loss: 0.8954
# Epoch 4/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9783 - loss: 0.1872 - val_accuracy: 0.7438 - val_loss: 0.8872
# Epoch 5/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9909 - loss: 0.1196 - val_accuracy: 0.7341 - val_loss: 0.9170
# Epoch 6/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9901 - loss: 0.1174 - val_accuracy: 0.7416 - val_loss: 0.9007
# Epoch 7/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9965 - loss: 0.0886 - val_accuracy: 0.7361 - val_loss: 0.9365
# Epoch 8/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9939 - loss: 0.0745 - val_accuracy: 0.7365 - val_loss: 0.9475
# Epoch 9/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9966 - loss: 0.0641 - val_accuracy: 0.7356 - val_loss: 0.9572
# Epoch 10/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9990 - loss: 0.0558 - val_accuracy: 0.7396 - val_loss: 0.9673
# Epoch 11/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9992 - loss: 0.0452 - val_accuracy: 0.7369 - val_loss: 1.0098
# Epoch 12/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 0.7387 - val_loss: 0.9989
# Epoch 13/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0337 - val_accuracy: 0.7356 - val_loss: 1.0303
# Epoch 14/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.7374 - val_loss: 1.0354
# Epoch 15/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0258 - val_accuracy: 0.7354 - val_loss: 1.0654
# Epoch 16/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0248 - val_accuracy: 0.7354 - val_loss: 1.0677
# Epoch 17/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.7361 - val_loss: 1.0833
# Epoch 18/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.7376 - val_loss: 1.0929
# Epoch 19/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.7365 - val_loss: 1.1004
# Epoch 20/20
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.7343 - val_loss: 1.1222
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Active Learning Iteration 2/5
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# Epoch 1/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9484 - loss: 0.1910 - val_accuracy: 0.7174 - val_loss: 1.0767
# Epoch 2/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9660 - loss: 0.1471 - val_accuracy: 0.7488 - val_loss: 0.9377
# Epoch 3/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9861 - loss: 0.0770 - val_accuracy: 0.7682 - val_loss: 0.8676
# Epoch 4/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9983 - loss: 0.0441 - val_accuracy: 0.7666 - val_loss: 0.8938
# Epoch 5/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9977 - loss: 0.0309 - val_accuracy: 0.7664 - val_loss: 0.9085
# Epoch 6/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.7666 - val_loss: 0.9340
# Epoch 7/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.7616 - val_loss: 0.9570
# Epoch 8/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0173 - val_accuracy: 0.7666 - val_loss: 0.9698
# Epoch 9/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.7637 - val_loss: 0.9921
# Epoch 10/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.7607 - val_loss: 1.0056
# Epoch 11/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.7630 - val_loss: 1.0137
# Epoch 12/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.7639 - val_loss: 1.0239
# Epoch 13/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.7625 - val_loss: 1.0346
# Epoch 14/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.7628 - val_loss: 1.0464
# Epoch 15/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.7612 - val_loss: 1.0593
# Epoch 16/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.7639 - val_loss: 1.0641
# Epoch 17/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.7646 - val_loss: 1.0739
# Epoch 18/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7632 - val_loss: 1.0868
# Epoch 19/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7625 - val_loss: 1.0884
# Epoch 20/20
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.7630 - val_loss: 1.0983
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Active Learning Iteration 3/5
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step
# Epoch 1/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9585 - loss: 0.1725 - val_accuracy: 0.7561 - val_loss: 1.0768
# Epoch 2/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9765 - loss: 0.0995 - val_accuracy: 0.7593 - val_loss: 0.9608
# Epoch 3/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9852 - loss: 0.0686 - val_accuracy: 0.7810 - val_loss: 0.8598
# Epoch 4/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9911 - loss: 0.0535 - val_accuracy: 0.7720 - val_loss: 0.9149
# Epoch 5/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9990 - loss: 0.0206 - val_accuracy: 0.7851 - val_loss: 0.8758
# Epoch 6/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9974 - loss: 0.0190 - val_accuracy: 0.7814 - val_loss: 0.8766
# Epoch 7/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9985 - loss: 0.0138 - val_accuracy: 0.7775 - val_loss: 0.9056
# Epoch 8/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.7835 - val_loss: 0.9124
# Epoch 9/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.7814 - val_loss: 0.9131
# Epoch 10/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.7803 - val_loss: 0.9268
# Epoch 11/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.7819 - val_loss: 0.9391
# Epoch 12/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.7835 - val_loss: 0.9477
# Epoch 13/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.7824 - val_loss: 0.9527
# Epoch 14/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.7821 - val_loss: 0.9653
# Epoch 15/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.7824 - val_loss: 0.9731
# Epoch 16/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.7819 - val_loss: 0.9777
# Epoch 17/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.7828 - val_loss: 0.9899
# Epoch 18/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.7826 - val_loss: 0.9936
# Epoch 19/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.7830 - val_loss: 0.9995
# Epoch 20/20
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7821 - val_loss: 1.0063
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Active Learning Iteration 4/5
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 14s 937ms/step - accuracy: 0.9682 - loss: 0.1411 - val_accuracy: 0.7845 - val_loss: 0.9330
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9820 - loss: 0.0717 - val_accuracy: 0.7878 - val_loss: 0.8979
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9859 - loss: 0.0738 - val_accuracy: 0.7944 - val_loss: 0.8536
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9942 - loss: 0.0360 - val_accuracy: 0.7904 - val_loss: 0.8697
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9999 - loss: 0.0175 - val_accuracy: 0.8026 - val_loss: 0.8442
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9996 - loss: 0.0130 - val_accuracy: 0.8033 - val_loss: 0.8388
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9983 - loss: 0.0113 - val_accuracy: 0.8024 - val_loss: 0.8355
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9980 - loss: 0.0091 - val_accuracy: 0.8036 - val_loss: 0.8536
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8062 - val_loss: 0.8708
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.8024 - val_loss: 0.8778
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8015 - val_loss: 0.8821
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8003 - val_loss: 0.8800
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8019 - val_loss: 0.8997
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8003 - val_loss: 0.9116
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.7996 - val_loss: 0.9162
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8005 - val_loss: 0.9195
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7998 - val_loss: 0.9259
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8000 - val_loss: 0.9366
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7996 - val_loss: 0.9425
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7991 - val_loss: 0.9453
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Active Learning Iteration 5/5
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 739ms/step - accuracy: 0.9742 - loss: 0.1021 - val_accuracy: 0.8034 - val_loss: 0.8659
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9901 - loss: 0.0371 - val_accuracy: 0.8123 - val_loss: 0.8292
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9967 - loss: 0.0199 - val_accuracy: 0.8056 - val_loss: 0.8837
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.8101 - val_loss: 0.8936
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9555 - loss: 0.1217 - val_accuracy: 0.7938 - val_loss: 0.8618
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9608 - loss: 0.1259 - val_accuracy: 0.7876 - val_loss: 0.9413
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9837 - loss: 0.0476 - val_accuracy: 0.8060 - val_loss: 0.8299
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9961 - loss: 0.0168 - val_accuracy: 0.8132 - val_loss: 0.8151
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8156 - val_loss: 0.8052
# Epoch 10/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8154 - val_loss: 0.8148
# Epoch 11/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8175 - val_loss: 0.8212
# Epoch 12/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.8171 - val_loss: 0.8245
# Epoch 13/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8171 - val_loss: 0.8329
# Epoch 14/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8178 - val_loss: 0.8385
# Epoch 15/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8183 - val_loss: 0.8448
# Epoch 16/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8185 - val_loss: 0.8469
# Epoch 17/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8190 - val_loss: 0.8545
# Epoch 18/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8175 - val_loss: 0.8654
# Epoch 19/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8171 - val_loss: 0.8681
# Epoch 20/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8175 - val_loss: 0.8711
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e632b9b7426f> in <cell line: 133>()
#     131     return model
#     132 # Main
# --> 133 model = main_pipeline(WS, k, Num_Classes, CRDHSI, GT, Tr, TrC, Va, VaC, Te, TeC, num_iterations=5,
#     134                       query_percentage=0.02, epochs=epochs, batch_size=batch_size)
#
# <ipython-input-19-e632b9b7426f> in main_pipeline(WS, k, Num_Classes, CRDHSI, GT, Tr, TrC, Va, VaC, Te, TeC, num_iterations, query_percentage, epochs, batch_size)
#     106         # Save the model during the last iteration
#     107         if i == num_iterations:
# --> 108             model.save(f"{HSID}_trained_ssvit_model.tf")
#     109             print(f"Model saved at iteration {i} as 'final_model_iteration.tf'")
#     110
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in save_model(model, filepath, overwrite, zipped, **kwargs)
#     112             model, filepath, overwrite, include_optimizer
#     113         )
# --> 114     raise ValueError(
#     115         "Invalid filepath extension for saving. "
#     116         "Please add either a `.keras` extension for the native Keras "
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=IP_trained_ssvit_model.tf.
